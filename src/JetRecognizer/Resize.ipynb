# %%
import sys
from pathlib import Path
home = str(Path.home())
# sys.path.append(f"{home}/Desktop/Dev/Python Projects/JetRecognizer")
sys.path.append(f"{home}/Desktop/ML/JetRecognizer/src")
sys.path
# Out:
# ['/home/paperspace/Desktop/ML/PlaneRecognizer/src/JetRecognizer',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python39.zip',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python3.9',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python3.9/lib-dynload',
#  '',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python3.9/site-packages',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python3.9/site-packages/IPython/extensions',
#  '/home/paperspace/.ipython',
#  '/home/paperspace/Desktop/ML/BuildingNeuralNets',
#  '/home/paperspace/Desktop/ML/BuildingNeuralNets/src',
#  '/home/paperspace/Desktop/ML/JetRecognizer',
#  '/home/paperspace/Desktop/ML/JetRecognizer/src']

# %%
from JetRecognizer.JetRecognizerPreprocessing import resize_fighter_images
from Common.DL_FilePaths import get_fighter_jet_dir, IMG_SIZE, FIGHTER_JET
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_5246/4236469623.py in <module>
# ----> 1 from JetRecognizer.JetRecognizerPreprocessing import resize_fighter_images
#       2 from Common.DL_FilePaths import get_fighter_jet_dir, IMG_SIZE, FIGHTER_JET
#
# ~/Desktop/ML/PlaneRecognizer/src/JetRecognizer/JetRecognizer.py in <module>
# ----> 1 from src.ImagePreprocessing.ImagePreprocessing import load_label_encoder, save_label_encoder, \
#       2     convert_labels_to_one_hot_vectors
#       3 from JetRecognizerPreprocessing import get_random_train_fighter_images_as_pixel_values_generator, \
#       4     get_random_validation_fighter_images_as_pixel_values_generator
#       5 from BatchLoopGenerator import image_batch_loop
#
# ModuleNotFoundError: No module named 'src'

# %%
get_fighter_jet_dir(FIGHTER_JET.F_22, IMG_SIZE.IS_960)
# Out:
# '/home/paperspace/Desktop/DeepLearning/F-22_Detector/960/F-22s'

# %%
resize_fighter_images()
# Out:
# resize_fighter_images took time: 29.488538890999962 seconds, 0.4914756481833327 minutes
