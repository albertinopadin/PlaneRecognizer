# %%
import sys
from pathlib import Path
home = str(Path.home())
sys.path.append(f"{home}/Desktop/Dev/Python Projects/BuildingNeuralNets")
# sys.path.append(f"{home}/Desktop/ML/BuildingNeuralNets")
sys.path
# Out:
# ['/Users/albertinopadin/Desktop/Dev/Python Projects/BuildingNeuralNets/F22_Detector',
#  '/Users/albertinopadin/Desktop/Dev/Python Projects/BuildingNeuralNets',
#  '/Users/albertinopadin/miniforge3/envs/dev/lib/python39.zip',
#  '/Users/albertinopadin/miniforge3/envs/dev/lib/python3.9',
#  '/Users/albertinopadin/miniforge3/envs/dev/lib/python3.9/lib-dynload',
#  '',
#  '/Users/albertinopadin/miniforge3/envs/dev/lib/python3.9/site-packages',
#  '/Users/albertinopadin/miniforge3/envs/dev/lib/python3.9/site-packages/IPython/extensions',
#  '/Users/albertinopadin/.ipython',
#  '/Users/albertinopadin/Desktop/Dev/Python Projects/BuildingNeuralNets']

# %%
from F22_Detector_Preprocessing import resize_fighter_images
from Common.DL_FilePaths import get_fighter_jet_dir, IMG_SIZE, FIGHTER_JET
# Out:
# 2021-12-27 04:53:10.705365: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
get_fighter_jet_dir(FIGHTER_JET.F_22, IMG_SIZE.IS_960)
# Out:
# '/home/paperspace/Desktop/DeepLearning/F-22_Detector/960/F-22s'

# %%
resize_fighter_images()
# Out:
# resize_fighter_images took time: 29.488538890999962 seconds, 0.4914756481833327 minutes
