# %%
import sys
import os
from pathlib import Path
curr_dir = os.path.abspath('')
project_dir = Path(curr_dir).parent
sys.path.append(f"{project_dir}")
sys.path.append(f"{project_dir}/src")
sys.path
# Out:
# ['/home/paperspace/Desktop/ML/PlaneRecognizer/src/JetRecognizer',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python39.zip',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python3.9',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python3.9/lib-dynload',
#  '',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python3.9/site-packages',
#  '/home/paperspace/src/miniconda/envs/ml/lib/python3.9/site-packages/IPython/extensions',
#  '/home/paperspace/.ipython',
#  '/home/paperspace/Desktop/ML/PlaneRecognizer',
#  '/home/paperspace/Desktop/ML/PlaneRecognizer/src']

# %%
from src.JetRecognizer.JetRecognizerPreprocessing import resize_fighter_images
from Common.DL_FilePaths import get_fighter_jet_dir, IMG_SIZE, FIGHTER_JET

# %%
# from src.ImagePreprocessing import ImagePreprocessing
# from Common import DL_FilePaths

# %%
get_fighter_jet_dir(FIGHTER_JET.F_22, IMG_SIZE.IS_960)
# Out:
# '/home/paperspace/Desktop/DeepLearning/F-22_Detector/960/F-22s'

# %%
resize_fighter_images()
# Out:
# resize_fighter_images took time: 66.42563697399964 seconds, 1.1070939495666607 minutes
